# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el conjunto de datos
ruta_archivo = "C:/Users/Usuario/Documents/Henry/PI/Dataset/movies_dataset_modificado.csv"
dataset = pd.read_csv(ruta_archivo)

# Vista general del conjunto de datos
print(dataset.head())  # Muestra las primeras filas del conjunto de datos
print(dataset.shape)  # Muestra la cantidad de filas y columnas del conjunto de datos
print(dataset.describe())  # Estadísticas descriptivas de las columnas numéricas

# Análisis de variables individuales
# Histograma de la variable 'vote_average'
sns.histplot(data=dataset, x='vote_average', bins=20)
plt.title('Distribución de las puntuaciones promedio de las películas')
plt.xlabel('Puntuación promedio')
plt.ylabel('Frecuencia')
plt.show()

# Gráfico de barras de los géneros más frecuentes
genres_count = dataset['genres'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=genres_count.values, y=genres_count.index)
plt.title('Géneros más frecuentes')
plt.xlabel('Cantidad')
plt.ylabel('Género')
plt.show()

# Matriz de correlación entre variables numéricas
numeric_columns = ['budget', 'revenue', 'runtime', 'vote_average', 'vote_count']
correlation_matrix = dataset[numeric_columns].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de correlación')
plt.show()

# Análisis de valores faltantes
missing_values = dataset.isnull().sum()
plt.figure(figsize=(10, 6))
sns.barplot(x=missing_values.values, y=missing_values.index)
plt.title('Valores faltantes en el conjunto de datos')
plt.xlabel('Cantidad de valores faltantes')
plt.ylabel('Variable')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_5892\1591460053.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv(ruta_archivo)
#             belongs_to_collection      budget                      genres  \
# 0            Toy Story Collection  30000000.0   Animation, Comedy, Family
# 1                             NaN  65000000.0  Adventure, Fantasy, Family
# 2       Grumpy Old Men Collection         0.0             Romance, Comedy
# 3                             NaN  16000000.0      Comedy, Drama, Romance
# 4  Father of the Bride Collection         0.0                      Comedy
#
#       id original_language                                           overview  \
# 0    862                en  Led by Woody, Andy's toys live happily in his ...
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# ...
